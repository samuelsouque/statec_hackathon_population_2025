# %%
import pandas as pd

file = "alone.csv"
df = pd.read_csv(file)
df
# Out:
#     STRUCTURE                             STRUCTURE_ID  \
# 0    DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 1    DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 2    DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 3    DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 4    DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# ..        ...                                      ...
# 103  DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 104  DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 105  DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 106  DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
# 107  DATAFLOW  LU1:DSD_CENSUS_GROUP21_24@DF_B1678(1.0)
#
#                                         STRUCTURE_NAME ACTION UNIT_MEASURE  \
# 0    Working status by household status, marital st...      I         PERS
# 1    Working status by household status, marital st...      I         PERS
# 2    Working status by household status, marital st...      I         PERS
# ...

# %%
df.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'UNIT_MEASURE',
#        'Unit of measure', 'MEASURE', 'Measure', 'FREQ', 'Frequency', 'SEX',
#        'Sex', 'AGE', 'Age class', 'LMS', 'Legal marital status', 'HST',
#        'Household status', 'FST', 'Familly status', 'HAR',
#        'Housing arrangements', 'LOC_SIZE', 'Size of the locality', 'WSTATUS',
#        'Working status', 'ISCO08', 'Occupation (ISCO-08)', 'EDU',
#        'Educational level', 'SIE', 'Employment status', 'LPW', 'Place of work',
#        'C_BIRTH', 'Country of birth', 'CITIZEN', 'Citizenship', 'YAE',
#        'Year of arrival in the country since 1980', 'YAT',
#        'Year of arrival in the country since 2010', 'ROY',
#        'Place of usual residence one year prior to the census', 'GEO',
#        'Geographic level', 'ACTIVITY', 'Economic activity (NACE Rev.2)',
#        'TIME_PERIOD', 'Time period', 'OBS_VALUE', 'Observation value',
#        'UNIT_MULT', 'Unit multiplier'],
# ...

# %%
perc = (26954 + 5613) / (80075 + 9475)
print(f"{perc*100:.2f}%")
# Out:
# 36.37%
